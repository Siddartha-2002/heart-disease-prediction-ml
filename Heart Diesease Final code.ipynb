# %%
# ===============================
# 1. Import libraries
# ===============================

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
# ===============================
# 2. Load dataset
# ===============================

df = pd.read_csv("heart_statlog_cleveland_hungary_final.csv")

df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
# ===============================
# 3. Clean column names
# ===============================

df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

df.head()
# Out:
#    age  sex  chest_pain_type  resting_bp_s  cholesterol  fasting_blood_sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting_ecg  max_heart_rate  exercise_angina  oldpeak  st_slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
# Check columns
print(df.columns)
# Out:
# Index(['age', 'sex', 'chest_pain_type', 'resting_bp_s', 'cholesterol',
#        'fasting_blood_sugar', 'resting_ecg', 'max_heart_rate',
#        'exercise_angina', 'oldpeak', 'st_slope', 'target'],
#       dtype='object')

# %%
# ===============================
# 4. Basic data checking
# ===============================

print("Shape:", df.shape)
print("\nMissing values:")
print(df.isnull().sum())

print("\nDuplicate rows:", df.duplicated().sum())

print("\nTarget values:")
print(df["target"].value_counts())
# Out:
# Shape: (1190, 12)
#
# Missing values:
# age                    0
# sex                    0
# chest_pain_type        0
# resting_bp_s           0
# cholesterol            0
# fasting_blood_sugar    0
# resting_ecg            0
# max_heart_rate         0
# exercise_angina        0
# oldpeak                0
# st_slope               0
# target                 0
# dtype: int64
#
# Duplicate rows: 272
#
# Target values:
# target
# 1    629
# 0    561
# Name: count, dtype: int64

# %%
# ===============================
# 5. Remove duplicate rows
# ===============================

df = df.drop_duplicates()

print("Shape after removing duplicates:", df.shape)
# Out:
# Shape after removing duplicates: (918, 12)

# %%
# ===============================
# 6. Replace unrealistic zero values with NaN
# ===============================

df["cholesterol"] = df["cholesterol"].replace(0, np.nan)
df["resting_bp_s"] = df["resting_bp_s"].replace(0, np.nan)
df["st_slope"] = df["st_slope"].replace(0, np.nan)

print(df.isnull().sum())
# Out:
# age                      0
# sex                      0
# chest_pain_type          0
# resting_bp_s             1
# cholesterol            172
# fasting_blood_sugar      0
# resting_ecg              0
# max_heart_rate           0
# exercise_angina          0
# oldpeak                  0
# st_slope                 1
# target                   0
# dtype: int64

# %%
# ===============================
# 7. Basic dataset overview
# ===============================

print("Dataset shape:", df.shape)
print("\nColumn names:")
print(df.columns)

print("\nDataset information:")
print(df.info())

print("\nSummary statistics:")
display(df.describe())

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Dataset shape: (918, 12)
#
# Column names:
# Index(['age', 'sex', 'chest_pain_type', 'resting_bp_s', 'cholesterol',
#        'fasting_blood_sugar', 'resting_ecg', 'max_heart_rate',
#        'exercise_angina', 'oldpeak', 'st_slope', 'target'],
#       dtype='object')
#
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# Index: 918 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  918 non-null    int64
#  1   sex                  918 non-null    int64
#  2   chest_pain_type      918 non-null    int64
#  3   resting_bp_s         917 non-null    float64
#  4   cholesterol          746 non-null    float64
#  5   fasting_blood_sugar  918 non-null    int64
#  6   resting_ecg          918 non-null    int64
#  7   max_heart_rate       918 non-null    int64
#  8   exercise_angina      918 non-null    int64
# ...

# %%
# ===============================
# 8. Target variable distribution
# ===============================

import matplotlib.pyplot as plt
import seaborn as sns

print(df["target"].value_counts())
print(df["target"].value_counts(normalize=True) * 100)

plt.figure(figsize=(6,4))
sns.countplot(data=df, x="target")
plt.title("Distribution of Heart Disease Target")
plt.xlabel("Target: 0 = No Heart Disease, 1 = Heart Disease")
plt.ylabel("Count")
plt.show()
# Out:
# target
# 1    508
# 0    410
# Name: count, dtype: int64
# target
# 1    55.337691
# 0    44.662309
# Name: proportion, dtype: float64

# %%
# ===============================
# 9. Distribution of numerical features
# ===============================

numeric_features = [
    "age",
    "resting_bp_s",
    "cholesterol",
    "max_heart_rate",
    "oldpeak"
]

df[numeric_features].hist(figsize=(12, 8), bins=20)
plt.suptitle("Distribution of Numerical Features")
plt.show()

# %%
# ===============================
# 10. Boxplots for outlier detection
# ===============================

for col in numeric_features:
    plt.figure(figsize=(6,4))
    sns.boxplot(data=df, x=col)
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
# ===============================
# 12. Distribution of categorical features
# ===============================

categorical_features = [
    "sex",
    "chest_pain_type",
    "fasting_blood_sugar",
    "resting_ecg",
    "exercise_angina",
    "st_slope"
]

for col in categorical_features:
    plt.figure(figsize=(6,4))
    sns.countplot(data=df, x=col)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
# ===============================
# Correlation heatmap
# ===============================

plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# ===============================
# 15. Import modeling libraries
# ===============================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer

from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix,
    roc_curve
)

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

import warnings
warnings.filterwarnings("ignore")

# %%
# ===============================
# 16. Define features and target
# ===============================

target_col = "target"

feature_cols = [
    "age",
    "sex",
    "chest_pain_type",
    "resting_bp_s",
    "cholesterol",
    "fasting_blood_sugar",
    "resting_ecg",
    "max_heart_rate",
    "exercise_angina",
    "oldpeak",
    "st_slope"
]

X = df[feature_cols].copy()
y = df[target_col].copy()

print("X shape:", X.shape)
print("y shape:", y.shape)

print("\nTarget distribution:")
print(y.value_counts())
# Out:
# X shape: (918, 11)
# y shape: (918,)
#
# Target distribution:
# target
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
# ===============================
# 17. Define numerical and categorical columns
# ===============================

numeric_features = [
    "age",
    "resting_bp_s",
    "cholesterol",
    "max_heart_rate",
    "oldpeak"
]

categorical_features = [
    "sex",
    "chest_pain_type",
    "fasting_blood_sugar",
    "resting_ecg",
    "exercise_angina",
    "st_slope"
]

print("Numerical features:", numeric_features)
print("Categorical features:", categorical_features)
# Out:
# Numerical features: ['age', 'resting_bp_s', 'cholesterol', 'max_heart_rate', 'oldpeak']
# Categorical features: ['sex', 'chest_pain_type', 'fasting_blood_sugar', 'resting_ecg', 'exercise_angina', 'st_slope']

# %%
# ===============================
# 18. Train-test split
# ===============================

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)

print("\nTraining target distribution:")
print(y_train.value_counts())

print("\nTesting target distribution:")
print(y_test.value_counts())
# Out:
# X_train shape: (734, 11)
# X_test shape: (184, 11)
# y_train shape: (734,)
# y_test shape: (184,)
#
# Training target distribution:
# target
# 1    406
# 0    328
# Name: count, dtype: int64
#
# Testing target distribution:
# target
# 1    102
# 0     82
# Name: count, dtype: int64

# %%
# ===============================
# 19. Handle missing values
# ===============================

X_train_processed = X_train.copy()
X_test_processed = X_test.copy()

# Numerical columns: fill missing values using median
num_imputer = SimpleImputer(strategy="median")

X_train_processed[numeric_features] = num_imputer.fit_transform(
    X_train_processed[numeric_features]
)

X_test_processed[numeric_features] = num_imputer.transform(
    X_test_processed[numeric_features]
)

# Categorical columns: fill missing values using most frequent value
cat_imputer = SimpleImputer(strategy="most_frequent")

X_train_processed[categorical_features] = cat_imputer.fit_transform(
    X_train_processed[categorical_features]
)

X_test_processed[categorical_features] = cat_imputer.transform(
    X_test_processed[categorical_features]
)

print("Missing values in X_train after imputation:")
print(X_train_processed.isnull().sum())

print("\nMissing values in X_test after imputation:")
print(X_test_processed.isnull().sum())
# Out:
# Missing values in X_train after imputation:
# age                    0
# sex                    0
# chest_pain_type        0
# resting_bp_s           0
# cholesterol            0
# fasting_blood_sugar    0
# resting_ecg            0
# max_heart_rate         0
# exercise_angina        0
# oldpeak                0
# st_slope               0
# dtype: int64
#
# Missing values in X_test after imputation:
# age                    0
# sex                    0
# chest_pain_type        0
# resting_bp_s           0
# cholesterol            0
# fasting_blood_sugar    0
# resting_ecg            0
# max_heart_rate         0
# exercise_angina        0
# oldpeak                0
# st_slope               0
# dtype: int64

# %%
# ===============================
# 20. Label encode categorical columns
# ===============================

label_encoders = {}

for col in categorical_features:
    le = LabelEncoder()

    X_train_processed[col] = le.fit_transform(X_train_processed[col].astype(str))
    X_test_processed[col] = le.transform(X_test_processed[col].astype(str))

    label_encoders[col] = le

print("Label encoding completed.")

X_train_processed.head()
# Out:
# Label encoding completed.
#       age  sex  chest_pain_type  resting_bp_s  cholesterol  \
# 486  63.0    1                1         139.0        217.0
# 487  55.0    1                1         110.0        214.0
# 117  59.0    0                3         130.0        338.0
# 362  47.0    1                3         160.0        238.0
# 297  50.0    1                3         145.0        238.0
#
#      fasting_blood_sugar  resting_ecg  max_heart_rate  exercise_angina  \
# 486                    1            1           128.0                1
# 487                    1            1           180.0                0
# 117                    1            1           130.0                1
# 362                    0            0           124.0                1
# 297                    1            0           139.0                1
#
#      oldpeak  st_slope
# 486      1.2         1
# 487      0.4         0
# 117      1.5         1
# 362      0.0         1
# 297      0.7         1

# %%
# ===============================
# 21. Standard scaling
# ===============================

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train_processed)
X_test_scaled = scaler.transform(X_test_processed)

print("X_train_scaled shape:", X_train_scaled.shape)
print("X_test_scaled shape:", X_test_scaled.shape)
# Out:
# X_train_scaled shape: (734, 11)
# X_test_scaled shape: (184, 11)

# %%
# ===============================
# 22. Model evaluation function
# ===============================

model_results = []

def evaluate_model(model_name, y_true, y_pred, y_pred_proba):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    roc_auc = roc_auc_score(y_true, y_pred_proba)

    model_results.append({
        "Model": model_name,
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "ROC-AUC": roc_auc
    })

    print("=" * 50)
    print(model_name)
    print("=" * 50)
    print("Accuracy :", accuracy)
    print("Precision:", precision)
    print("Recall   :", recall)
    print("F1 Score :", f1)
    print("ROC-AUC  :", roc_auc)

    print("\nClassification Report:")
    print(classification_report(y_true, y_pred))

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

# %%
# ===============================
# 23. Random Forest model
# ===============================

rf_model = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight="balanced"
)

rf_model.fit(X_train_processed, y_train)

rf_pred = rf_model.predict(X_test_processed)
rf_pred_proba = rf_model.predict_proba(X_test_processed)[:, 1]

evaluate_model(
    "Random Forest",
    y_test,
    rf_pred,
    rf_pred_proba
)
# Out:
# ...
# Random Forest
# ...
# Accuracy : 0.8804347826086957
# Precision: 0.8846153846153846
# Recall   : 0.9019607843137255
# F1 Score : 0.8932038834951457
# ROC-AUC  : 0.9276661884265902
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86        82
#            1       0.88      0.90      0.89       102
#
#     accuracy                           0.88       184
#    macro avg       0.88      0.88      0.88       184
# weighted avg       0.88      0.88      0.88       184

# %%
# ===============================
# 24. XGBoost model
# ===============================

xgb_model = XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.85,
    colsample_bytree=0.85,
    objective="binary:logistic",
    eval_metric="logloss",
    random_state=42
)

xgb_model.fit(X_train_processed, y_train)

xgb_pred = xgb_model.predict(X_test_processed)
xgb_pred_proba = xgb_model.predict_proba(X_test_processed)[:, 1]

evaluate_model(
    "XGBoost",
    y_test,
    xgb_pred,
    xgb_pred_proba
)
# Out:
# ...
# XGBoost
# ...
# Accuracy : 0.8586956521739131
# Precision: 0.8958333333333334
# Recall   : 0.8431372549019608
# F1 Score : 0.8686868686868687
# ROC-AUC  : 0.9207317073170732
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85        82
#            1       0.90      0.84      0.87       102
#
#     accuracy                           0.86       184
#    macro avg       0.86      0.86      0.86       184
# weighted avg       0.86      0.86      0.86       184

# %%
# ===============================
# 25. ANN model
# ===============================

tf.random.set_seed(42)

ann_model = Sequential()

ann_model.add(Dense(64, activation="relu", input_shape=(X_train_scaled.shape[1],)))
ann_model.add(Dropout(0.30))

ann_model.add(Dense(32, activation="relu"))
ann_model.add(Dropout(0.20))

ann_model.add(Dense(16, activation="relu"))

ann_model.add(Dense(1, activation="sigmoid"))

ann_model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

ann_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ...

# %%
# ===============================
# 26. Train ANN model
# ===============================

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=15,
    restore_best_weights=True
)

history = ann_model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.20,
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6440 - loss: 0.6566 - val_accuracy: 0.7823 - val_loss: 0.5800
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7564 - loss: 0.5574 - val_accuracy: 0.7823 - val_loss: 0.5022
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8075 - loss: 0.4656 - val_accuracy: 0.7891 - val_loss: 0.4513
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8211 - loss: 0.4196 - val_accuracy: 0.8095 - val_loss: 0.4388
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8416 - loss: 0.3707 - val_accuracy: 0.8095 - val_loss: 0.4442
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8262 - loss: 0.3836 - val_accuracy: 0.8163 - val_loss: 0.4534
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8535 - loss: 0.3426 - val_accuracy: 0.8163 - val_loss: 0.4584
# Epoch 8/100
# ...

# %%
# ===============================
# 27. Evaluate ANN model
# ===============================

ann_pred_proba = ann_model.predict(X_test_scaled).ravel()

ann_pred = (ann_pred_proba >= 0.5).astype(int)

evaluate_model(
    "ANN",
    y_test,
    ann_pred,
    ann_pred_proba
)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# ...
# ANN
# ...
# Accuracy : 0.8695652173913043
# Precision: 0.8679245283018868
# Recall   : 0.9019607843137255
# F1 Score : 0.8846153846153846
# ROC-AUC  : 0.9085365853658537
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85        82
#            1       0.87      0.90      0.88       102
#
#     accuracy                           0.87       184
#    macro avg       0.87      0.87      0.87       184
# weighted avg       0.87      0.87      0.87       184

# %%
# ===============================
# 28. ANN training history
# ===============================

plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("ANN Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("ANN Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
# ===============================
# 29. Compare model performance
# ===============================

results_df = pd.DataFrame(model_results)

results_df = results_df.sort_values(
    by="ROC-AUC",
    ascending=False
).reset_index(drop=True)

results_df
# Out:
#            Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC
# 0  Random Forest  0.880435   0.884615  0.901961  0.893204  0.927666
# 1        XGBoost  0.858696   0.895833  0.843137  0.868687  0.920732
# 2            ANN  0.869565   0.867925  0.901961  0.884615  0.908537

# %%
# ===============================
# 31. ROC curve comparison
# ===============================

rf_fpr, rf_tpr, _ = roc_curve(y_test, rf_pred_proba)
xgb_fpr, xgb_tpr, _ = roc_curve(y_test, xgb_pred_proba)
ann_fpr, ann_tpr, _ = roc_curve(y_test, ann_pred_proba)

plt.figure(figsize=(8, 6))

plt.plot(rf_fpr, rf_tpr, label="Random Forest")
plt.plot(xgb_fpr, xgb_tpr, label="XGBoost")
plt.plot(ann_fpr, ann_tpr, label="ANN")

plt.plot([0, 1], [0, 1], linestyle="--", label="Random Guess")

plt.title("ROC Curve Comparison")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.legend()
plt.show()

# %%
# ===============================
# 30. Visual comparison of models
# ===============================

plt.figure(figsize=(10, 6))

comparison_df = results_df.set_index("Model")

comparison_df[["Accuracy", "Precision", "Recall", "F1 Score", "ROC-AUC"]].plot(
    kind="bar",
    figsize=(12, 6)
)

plt.title("Model Performance Comparison")
plt.ylabel("Score")
plt.ylim(0, 1)
plt.xticks(rotation=0)
plt.legend(loc="lower right")
plt.show()

# %%
# ===============================
# 35. Import hyperparameter tuning libraries
# ===============================

from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_auc_score
from scipy.stats import randint, uniform

import tensorflow as tf
from tensorflow.keras.optimizers import Adam

# %%
# ===============================
# 36. Hyperparameter tuning - Random Forest
# ===============================

rf_base = RandomForestClassifier(
    random_state=42,
    class_weight="balanced"
)

rf_param_grid = {
    "n_estimators": [100, 200, 300, 400, 500],
    "max_depth": [None, 5, 10, 15, 20, 30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["sqrt", "log2", None],
    "bootstrap": [True, False]
}

rf_random_search = RandomizedSearchCV(
    estimator=rf_base,
    param_distributions=rf_param_grid,
    n_iter=30,
    scoring="roc_auc",
    cv=5,
    random_state=42,
    n_jobs=-1,
    verbose=1
)

rf_random_search.fit(X_train_processed, y_train)

print("Best Random Forest Parameters:")
print(rf_random_search.best_params_)

print("\nBest Random Forest CV ROC-AUC:")
print(rf_random_search.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best Random Forest Parameters:
# {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 20, 'bootstrap': True}
#
# Best Random Forest CV ROC-AUC:
# 0.9281450878740852

# %%
# ===============================
# 37. Evaluate tuned Random Forest
# ===============================

best_rf_model = rf_random_search.best_estimator_

best_rf_pred = best_rf_model.predict(X_test_processed)
best_rf_pred_proba = best_rf_model.predict_proba(X_test_processed)[:, 1]

evaluate_model(
    "Tuned Random Forest",
    y_test,
    best_rf_pred,
    best_rf_pred_proba
)
# Out:
# ...
# Tuned Random Forest
# ...
# Accuracy : 0.875
# Precision: 0.8910891089108911
# Recall   : 0.8823529411764706
# F1 Score : 0.8866995073891626
# ROC-AUC  : 0.9276661884265902
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86        82
#            1       0.89      0.88      0.89       102
#
#     accuracy                           0.88       184
#    macro avg       0.87      0.87      0.87       184
# weighted avg       0.88      0.88      0.88       184

# %%
# ===============================
# 38. Hyperparameter tuning - XGBoost
# ===============================

xgb_base = XGBClassifier(
    objective="binary:logistic",
    eval_metric="logloss",
    random_state=42
)

xgb_param_grid = {
    "n_estimators": [100, 200, 300, 400, 500],
    "learning_rate": [0.01, 0.03, 0.05, 0.1, 0.2],
    "max_depth": [2, 3, 4, 5, 6],
    "subsample": [0.7, 0.8, 0.85, 0.9, 1.0],
    "colsample_bytree": [0.7, 0.8, 0.85, 0.9, 1.0],
    "gamma": [0, 0.1, 0.2, 0.3],
    "reg_lambda": [1, 1.5, 2, 3, 5]
}

xgb_random_search = RandomizedSearchCV(
    estimator=xgb_base,
    param_distributions=xgb_param_grid,
    n_iter=30,
    scoring="roc_auc",
    cv=5,
    random_state=42,
    n_jobs=-1,
    verbose=1
)

xgb_random_search.fit(X_train_processed, y_train)

print("Best XGBoost Parameters:")
print(xgb_random_search.best_params_)

print("\nBest XGBoost CV ROC-AUC:")
print(xgb_random_search.best_score_)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# Best XGBoost Parameters:
# {'subsample': 0.7, 'reg_lambda': 2, 'n_estimators': 500, 'max_depth': 3, 'learning_rate': 0.03, 'gamma': 0, 'colsample_bytree': 0.7}
#
# Best XGBoost CV ROC-AUC:
# 0.9271842179701257

# %%
# ===============================
# 39. Evaluate tuned XGBoost
# ===============================

best_xgb_model = xgb_random_search.best_estimator_

best_xgb_pred = best_xgb_model.predict(X_test_processed)
best_xgb_pred_proba = best_xgb_model.predict_proba(X_test_processed)[:, 1]

evaluate_model(
    "Tuned XGBoost",
    y_test,
    best_xgb_pred,
    best_xgb_pred_proba
)
# Out:
# ...
# Tuned XGBoost
# ...
# Accuracy : 0.875
# Precision: 0.898989898989899
# Recall   : 0.8725490196078431
# F1 Score : 0.8855721393034826
# ROC-AUC  : 0.9270683883309422
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86        82
#            1       0.90      0.87      0.89       102
#
#     accuracy                           0.88       184
#    macro avg       0.87      0.88      0.87       184
# weighted avg       0.88      0.88      0.88       184

# %%
# ===============================
# 40. Prepare validation data for ANN tuning
# ===============================

X_ann_train, X_ann_val, y_ann_train, y_ann_val = train_test_split(
    X_train_scaled,
    y_train,
    test_size=0.20,
    random_state=42,
    stratify=y_train
)

print("ANN training set:", X_ann_train.shape)
print("ANN validation set:", X_ann_val.shape)
# Out:
# ANN training set: (587, 11)
# ANN validation set: (147, 11)

# %%
# ===============================
# 41. ANN model-building function
# ===============================

def build_ann_model(
    input_dim,
    neurons_1=64,
    neurons_2=32,
    neurons_3=16,
    dropout_1=0.30,
    dropout_2=0.20,
    learning_rate=0.001
):
    model = Sequential()

    model.add(Dense(neurons_1, activation="relu", input_shape=(input_dim,)))
    model.add(Dropout(dropout_1))

    model.add(Dense(neurons_2, activation="relu"))
    model.add(Dropout(dropout_2))

    model.add(Dense(neurons_3, activation="relu"))

    model.add(Dense(1, activation="sigmoid"))

    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
# ===============================
# 42. Manual hyperparameter tuning - ANN
# ===============================

ann_param_grid = [
    {
        "neurons_1": 64,
        "neurons_2": 32,
        "neurons_3": 16,
        "dropout_1": 0.30,
        "dropout_2": 0.20,
        "learning_rate": 0.001,
        "batch_size": 32
    },
    {
        "neurons_1": 128,
        "neurons_2": 64,
        "neurons_3": 32,
        "dropout_1": 0.30,
        "dropout_2": 0.20,
        "learning_rate": 0.001,
        "batch_size": 32
    },
    {
        "neurons_1": 64,
        "neurons_2": 32,
        "neurons_3": 16,
        "dropout_1": 0.40,
        "dropout_2": 0.30,
        "learning_rate": 0.001,
        "batch_size": 32
    },
    {
        "neurons_1": 128,
        "neurons_2": 64,
        "neurons_3": 32,
        "dropout_1": 0.40,
        "dropout_2": 0.30,
        "learning_rate": 0.0005,
        "batch_size": 16
    },
    {
        "neurons_1": 32,
        "neurons_2": 16,
        "neurons_3": 8,
        "dropout_1": 0.20,
        "dropout_2": 0.10,
        "learning_rate": 0.001,
        "batch_size": 32
    }
]

ann_tuning_results = []

early_stop_tuning = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

for i, params in enumerate(ann_param_grid, start=1):
    print("=" * 60)
    print(f"Training ANN configuration {i}")
    print(params)
    print("=" * 60)

    tf.random.set_seed(42)

    temp_ann_model = build_ann_model(
        input_dim=X_ann_train.shape[1],
        neurons_1=params["neurons_1"],
        neurons_2=params["neurons_2"],
        neurons_3=params["neurons_3"],
        dropout_1=params["dropout_1"],
        dropout_2=params["dropout_2"],
        learning_rate=params["learning_rate"]
    )

    history_temp = temp_ann_model.fit(
        X_ann_train,
        y_ann_train,
        validation_data=(X_ann_val, y_ann_val),
        epochs=100,
        batch_size=params["batch_size"],
        callbacks=[early_stop_tuning],
        verbose=0
    )

    val_pred_proba = temp_ann_model.predict(X_ann_val).ravel()
    val_roc_auc = roc_auc_score(y_ann_val, val_pred_proba)

    ann_tuning_results.append({
        "Config": i,
        "Parameters": params,
        "Validation ROC-AUC": val_roc_auc,
        "Epochs Trained": len(history_temp.history["loss"])
    })

    print("Validation ROC-AUC:", val_roc_auc)
    print("Epochs trained:", len(history_temp.history["loss"]))
# Out:
# ...
# Training ANN configuration 1
# {'neurons_1': 64, 'neurons_2': 32, 'neurons_3': 16, 'dropout_1': 0.3, 'dropout_2': 0.2, 'learning_rate': 0.001, 'batch_size': 32}
# ...
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Validation ROC-AUC: 0.8991769547325102
# Epochs trained: 35
# ...
# Training ANN configuration 2
# {'neurons_1': 128, 'neurons_2': 64, 'neurons_3': 32, 'dropout_1': 0.3, 'dropout_2': 0.2, 'learning_rate': 0.001, 'batch_size': 32}
# ...

# %%
# ===============================
# 43. Select best ANN parameters
# ===============================

ann_tuning_df = pd.DataFrame(ann_tuning_results)

ann_tuning_df = ann_tuning_df.sort_values(
    by="Validation ROC-AUC",
    ascending=False
).reset_index(drop=True)

ann_tuning_df
# Out:
#    Config                                         Parameters  \
# 0       2  {'neurons_1': 128, 'neurons_2': 64, 'neurons_3...
# 1       1  {'neurons_1': 64, 'neurons_2': 32, 'neurons_3'...
# 2       4  {'neurons_1': 128, 'neurons_2': 64, 'neurons_3...
# 3       3  {'neurons_1': 64, 'neurons_2': 32, 'neurons_3'...
# 4       5  {'neurons_1': 32, 'neurons_2': 16, 'neurons_3'...
#
#    Validation ROC-AUC  Epochs Trained
# 0            0.908343              33
# 1            0.899177              35
# 2            0.829218              10
# 3            0.797419              10
# 4            0.481856              10

# %%
# ===============================
# 44. Train final tuned ANN
# ===============================

best_ann_params = ann_tuning_df.loc[0, "Parameters"]

print("Best ANN Parameters:")
print(best_ann_params)

tf.random.set_seed(42)

tuned_ann_model = build_ann_model(
    input_dim=X_train_scaled.shape[1],
    neurons_1=best_ann_params["neurons_1"],
    neurons_2=best_ann_params["neurons_2"],
    neurons_3=best_ann_params["neurons_3"],
    dropout_1=best_ann_params["dropout_1"],
    dropout_2=best_ann_params["dropout_2"],
    learning_rate=best_ann_params["learning_rate"]
)

early_stop_final = EarlyStopping(
    monitor="val_loss",
    patience=15,
    restore_best_weights=True
)

tuned_ann_history = tuned_ann_model.fit(
    X_train_scaled,
    y_train,
    validation_split=0.20,
    epochs=100,
    batch_size=best_ann_params["batch_size"],
    callbacks=[early_stop_final],
    verbose=1
)
# Out:
# Best ANN Parameters:
# {'neurons_1': 128, 'neurons_2': 64, 'neurons_3': 32, 'dropout_1': 0.3, 'dropout_2': 0.2, 'learning_rate': 0.001, 'batch_size': 32}
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6763 - loss: 0.6244 - val_accuracy: 0.8095 - val_loss: 0.5471
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8330 - loss: 0.4565 - val_accuracy: 0.7959 - val_loss: 0.4754
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8450 - loss: 0.3741 - val_accuracy: 0.8027 - val_loss: 0.4845
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8586 - loss: 0.3255 - val_accuracy: 0.8027 - val_loss: 0.5032
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8535 - loss: 0.3295 - val_accuracy: 0.7823 - val_loss: 0.5079
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8654 - loss: 0.3082 - val_accuracy: 0.7755 - val_loss: 0.5098
# Epoch 7/100
# ...

# %%
# ===============================
# 45. Evaluate tuned ANN
# ===============================

tuned_ann_pred_proba = tuned_ann_model.predict(X_test_scaled).ravel()

tuned_ann_pred = (tuned_ann_pred_proba >= 0.5).astype(int)

evaluate_model(
    "Tuned ANN",
    y_test,
    tuned_ann_pred,
    tuned_ann_pred_proba
)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# ...
# Tuned ANN
# ...
# Accuracy : 0.8695652173913043
# Precision: 0.8823529411764706
# Recall   : 0.8823529411764706
# F1 Score : 0.8823529411764706
# ROC-AUC  : 0.9197752271640364
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85        82
#            1       0.88      0.88      0.88       102
#
#     accuracy                           0.87       184
#    macro avg       0.87      0.87      0.87       184
# weighted avg       0.87      0.87      0.87       184

# %%
# ===============================
# 46. Base vs Tuned model comparison table
# ===============================

comparison_results_df = pd.DataFrame(model_results)

# Arrange models in a clear order
model_order = [
    "Random Forest",
    "Tuned Random Forest",
    "XGBoost",
    "Tuned XGBoost",
    "ANN",
    "Tuned ANN"
]

comparison_results_df["Model"] = pd.Categorical(
    comparison_results_df["Model"],
    categories=model_order,
    ordered=True
)

comparison_results_df = comparison_results_df.sort_values("Model").reset_index(drop=True)

comparison_results_df
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC
# 0        Random Forest  0.880435   0.884615  0.901961  0.893204  0.927666
# 1  Tuned Random Forest  0.875000   0.891089  0.882353  0.886700  0.927666
# 2              XGBoost  0.858696   0.895833  0.843137  0.868687  0.920732
# 3        Tuned XGBoost  0.875000   0.898990  0.872549  0.885572  0.927068
# 4                  ANN  0.869565   0.867925  0.901961  0.884615  0.908537
# 5            Tuned ANN  0.869565   0.882353  0.882353  0.882353  0.919775

# %%
# ===============================
# 47. Base vs Tuned model comparison plot
# ===============================

plot_df = comparison_results_df.set_index("Model")

metrics_to_plot = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1 Score",
    "ROC-AUC"
]

plt.figure(figsize=(14, 7))

plot_df[metrics_to_plot].plot(
    kind="bar",
    figsize=(14, 7)
)

plt.title("Base vs Tuned Model Performance Comparison")
plt.xlabel("Model")
plt.ylabel("Score")
plt.ylim(0, 1)
plt.xticks(rotation=45, ha="right")
plt.legend(title="Evaluation Metrics", loc="lower right")
plt.tight_layout()
plt.show()
